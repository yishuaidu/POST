# %%
import pandas as pd

# %%
df = pd.read_csv('binary_train.csv')
df.head()
# Out:
#    banner_pos  site_id  app_id  device_model  click
# 0           0        0       0            44      0
# 1           0        0       0            53      0
# 2           0        0       0            70      0
# 3           0        0       0           104      0
# 4           0        0       0           121      0

# %%
df.app_id.unique()
# Out:
# array([   0,    2,    4, ..., 8139, 8152, 8489])

# %%
df.site_id.unique()
# Out:
# array([   0,    2,    3, ..., 4229, 4734, 3316])

# %%
df.app_id.unique()
# Out:
# array([   0,    2,    4, ..., 8139, 8152, 8489])

# %%
df.device_model.unique()
# Out:
# array([  44,   53,   70, ..., 6401, 7243, 8126])

# %%
df[df.click == 1]
# Out:
#         banner_pos  site_id  app_id  device_model  click
# 269684           0        0       0             0      1
# 269685           0        0       0             1      1
# 269686           0        0       0             2      1
# 269687           0        0       0             3      1
# 269688           0        0       0             4      1
# 269689           0        0       0             5      1
# 269690           0        0       0             6      1
# 269691           0        0       0             7      1
# 269692           0        0       0             9      1
# 269693           0        0       0            10      1
# 269694           0        0       0            11      1
# 269695           0        0       0            12      1
# 269696           0        0       0            14      1
# 269697           0        0       0            15      1
# 269698           0        0       0            16      1
# ...
